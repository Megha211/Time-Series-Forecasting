# %% [markdown]
# ### Fetching AAPL Stock Data using Tiingo API

# %% [markdown]
# #### About
# This code fetches historical stock data for Apple Inc. (AAPL) from the Tiingo API and stores it in a CSV file for further use in financial modeling.
#
# #### Key Steps:
# - **Install Required Libraries:**
#   - Install essential packages such as `tiingo`, `pandas`, `python-dotenv`, `setuptools`, `tensorflow`, `numpy`, `matplotlib`, and `scikit-learn`.
#   - Install `statsmodels` for time-series analysis.
#
# - **API Setup:**
#   - Use `TiingoClient` from the Tiingo API for fetching stock data.
#   - Load API keys using `dotenv` to manage sensitive information securely.
#
# - **Data Retrieval:**
#   - Set up a configuration dictionary with the `api_key` for the Tiingo API.
#   - Specify the stock symbol (`AAPL`), date range (`2015-01-01` to `2024-12-31`), and data frequency (`daily`).
#
# - **Data Storage:**
#   - Fetch the stock data using `TiingoClient.get_dataframe()` and store the results in a pandas DataFrame.
#   - Export the DataFrame to a CSV file (`AAPL_data.csv`) for further use.
#
# This process ensures that AAPL's historical stock data is readily available for analysis and modeling in later stages.

# %% [markdown]
# #### Installing libraries

# %%
# %pip install tiingo pandas python-dotenv setuptools tensorflow numpy matplotlib scikit-learn statsmodels
# Out:
# Requirement already satisfied: tiingo in ./.venv/lib/python3.9/site-packages (0.15.6)
# Requirement already satisfied: pandas in ./.venv/lib/python3.9/site-packages (2.2.2)
# Requirement already satisfied: python-dotenv in ./.venv/lib/python3.9/site-packages (1.0.1)
# Requirement already satisfied: setuptools in ./.venv/lib/python3.9/site-packages (58.0.4)
# Requirement already satisfied: tensorflow in ./.venv/lib/python3.9/site-packages (2.17.0)
# Requirement already satisfied: numpy in ./.venv/lib/python3.9/site-packages (1.26.4)
# Requirement already satisfied: matplotlib in ./.venv/lib/python3.9/site-packages (3.9.1.post1)
# Requirement already satisfied: scikit-learn in ./.venv/lib/python3.9/site-packages (1.5.1)
# Requirement already satisfied: requests in ./.venv/lib/python3.9/site-packages (from tiingo) (2.32.3)
# Requirement already satisfied: websocket-client in ./.venv/lib/python3.9/site-packages (from tiingo) (1.8.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.9/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.9/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.9/site-packages (from pandas) (2024.1)
# Requirement already satisfied: absl-py>=1.0.0 in ./.venv/lib/python3.9/site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in ./.venv/lib/python3.9/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in ./.venv/lib/python3.9/site-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in ./.venv/lib/python3.9/site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in ./.venv/lib/python3.9/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in ./.venv/lib/python3.9/site-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in ./.venv/lib/python3.9/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in ./.venv/lib/python3.9/site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in ./.venv/lib/python3.9/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in ./.venv/lib/python3.9/site-packages (from tensorflow) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in ./.venv/lib/python3.9/site-packages (from tensorflow) (4.25.4)
# Requirement already satisfied: six>=1.12.0 in ./.venv/lib/python3.9/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in ./.venv/lib/python3.9/site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in ./.venv/lib/python3.9/site-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in ./.venv/lib/python3.9/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in ./.venv/lib/python3.9/site-packages (from tensorflow) (1.65.4)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in ./.venv/lib/python3.9/site-packages (from tensorflow) (2.17.0)
# Requirement already satisfied: keras>=3.2.0 in ./.venv/lib/python3.9/site-packages (from tensorflow) (3.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in ./.venv/lib/python3.9/site-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.9/site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.9/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.9/site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib/python3.9/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: pillow>=8 in ./.venv/lib/python3.9/site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.venv/lib/python3.9/site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in ./.venv/lib/python3.9/site-packages (from matplotlib) (6.4.0)
# Requirement already satisfied: scipy>=1.6.0 in ./.venv/lib/python3.9/site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in ./.venv/lib/python3.9/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in ./.venv/lib/python3.9/site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in ./.venv/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow) (0.44.0)
# Requirement already satisfied: zipp>=3.1.0 in ./.venv/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.19.2)
# Requirement already satisfied: rich in ./.venv/lib/python3.9/site-packages (from keras>=3.2.0->tensorflow) (13.7.1)
# Requirement already satisfied: namex in ./.venv/lib/python3.9/site-packages (from keras>=3.2.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in ./.venv/lib/python3.9/site-packages (from keras>=3.2.0->tensorflow) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.9/site-packages (from requests->tiingo) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.9/site-packages (from requests->tiingo) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.venv/lib/python3.9/site-packages (from requests->tiingo) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.9/site-packages (from requests->tiingo) (2024.7.4)
# Requirement already satisfied: markdown>=2.6.8 in ./.venv/lib/python3.9/site-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in ./.venv/lib/python3.9/site-packages (from tensorboard<2.18,>=2.17->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in ./.venv/lib/python3.9/site-packages (from tensorboard<2.18,>=2.17->tensorflow) (3.0.3)
# Requirement already satisfied: importlib-metadata>=4.4 in ./.venv/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard<2.18,>=2.17->tensorflow) (8.2.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in ./.venv/lib/python3.9/site-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./.venv/lib/python3.9/site-packages (from rich->keras>=3.2.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./.venv/lib/python3.9/site-packages (from rich->keras>=3.2.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in ./.venv/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# #### Importing Libraries

# %%
from tiingo import TiingoClient
import pandas as pd
import os
from dotenv import load_dotenv

# %%
api_key = os.getenv('TIINGO_API_KEY')

config = {
    'api_key': '6dede33366989b5a66a7f0cd3cfa06b8f3b547c6'
}

# %%
print(config)
# Out:
# {'api_key': '6dede33366989b5a66a7f0cd3cfa06b8f3b547c6'}

# %% [markdown]
# #### Calling Tingo API for data

# %%
client = TiingoClient(config)

df = client.get_dataframe(
    'AAPL',
    startDate='2015-01-01',
    endDate='2024-12-31',
    frequency='daily'
)

# %% [markdown]
# #### Data

# %%
df
# Out:
#                             close    high       low     open    volume  \
# date
# 2015-01-02 00:00:00+00:00  109.33  111.44  107.3500  111.390  53204626
# 2015-01-05 00:00:00+00:00  106.25  108.65  105.4100  108.290  64285491
# 2015-01-06 00:00:00+00:00  106.26  107.43  104.6300  106.540  65797116
# 2015-01-07 00:00:00+00:00  107.75  108.20  106.6950  107.200  40105934
# 2015-01-08 00:00:00+00:00  111.89  112.15  108.7000  109.230  59364547
# ...                           ...     ...       ...      ...       ...
# 2024-08-26 00:00:00+00:00  227.18  227.28  223.8905  226.760  30602208
# 2024-08-27 00:00:00+00:00  228.03  228.85  224.8900  225.995  35934559
# 2024-08-28 00:00:00+00:00  226.49  229.86  225.6800  227.920  38052167
# 2024-08-29 00:00:00+00:00  229.79  232.92  228.8800  230.100  51906297
# 2024-08-30 00:00:00+00:00  229.00  230.40  227.4800  230.190  52990770
#
#                              adjClose     adjHigh      adjLow     adjOpen  \
# date
# 2015-01-02 00:00:00+00:00   24.372730   24.843109   23.931333   24.831962
# 2015-01-05 00:00:00+00:00   23.686112   24.221139   23.498852   24.140885
# 2015-01-06 00:00:00+00:00   23.688341   23.949167   23.324968   23.750761
# 2015-01-07 00:00:00+00:00   24.020504   24.120822   23.785315   23.897893
# 2015-01-08 00:00:00+00:00   24.943426   25.001388   24.232286   24.350438
# ...                               ...         ...         ...         ...
# 2024-08-26 00:00:00+00:00  227.180000  227.280000  223.890500  226.760000
# 2024-08-27 00:00:00+00:00  228.030000  228.850000  224.890000  225.995000
# 2024-08-28 00:00:00+00:00  226.490000  229.860000  225.680000  227.920000
# 2024-08-29 00:00:00+00:00  229.790000  232.920000  228.880000  230.100000
# 2024-08-30 00:00:00+00:00  229.000000  230.400000  227.480000  230.190000
#
#                            adjVolume  divCash  splitFactor
# date
# 2015-01-02 00:00:00+00:00  212818504      0.0          1.0
# 2015-01-05 00:00:00+00:00  257141964      0.0          1.0
# 2015-01-06 00:00:00+00:00  263188464      0.0          1.0
# 2015-01-07 00:00:00+00:00  160423736      0.0          1.0
# 2015-01-08 00:00:00+00:00  237458188      0.0          1.0
# ...                              ...      ...          ...
# 2024-08-26 00:00:00+00:00   30602208      0.0          1.0
# 2024-08-27 00:00:00+00:00   35934559      0.0          1.0
# 2024-08-28 00:00:00+00:00   38052167      0.0          1.0
# 2024-08-29 00:00:00+00:00   51906297      0.0          1.0
# 2024-08-30 00:00:00+00:00   52990770      0.0          1.0
#
# [2432 rows x 12 columns]

# %% [markdown]
# #### Saving the Data

# %%
df.to_csv("AAPL_data.csv")
