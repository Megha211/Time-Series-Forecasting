# %% [markdown]
# ### AAPL Stock Price Prediction using LSTM

# %% [markdown]
# #### About
# This project utilizes Long Short-Term Memory (LSTM) networks to predict Apple Inc. (AAPL) stock prices based on historical stock data. The model employs Keras for building and training the LSTM network.
#
# #### Key Steps:
# - **Data Preprocessing:**
#   - Load AAPL stock data and select the 'close' price column.
#   - Normalize the stock prices with `MinMaxScaler`.
#   - Split the dataset into training (70%) and testing (30%) sets.
#
# - **Dataset Creation:**
#   - Implement a `create_dataset()` function to transform the time-series data into supervised learning format with a specified `time_steps`.
#
# - **Model Architecture:**
#   - Build an LSTM-based model:
#     - Two LSTM layers: first with `return_sequences=True`, second without.
#     - Output layer: `Dense(1)` for regression.
#   - Compile the model using Adam optimizer and Mean Squared Error loss.
#
# - **Model Training:**
#   - Train the model for 100 epochs with a batch size of 64.
#
# - **Prediction & Evaluation:**
#   - Make predictions for both training and testing sets.
#   - Inverse scale the predictions back to original values.
#   - Compute Root Mean Squared Error (RMSE) for both train and test sets.
#
# - **Visualization:**
#   - Plot actual vs predicted stock prices for both training and testing data.

# %% [markdown]
# #### Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, LSTM, Dense
from sklearn.metrics import mean_squared_error
# Out:
# 2024-08-07 22:58:19.380866: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-08-07 22:58:19.386591: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-08-07 22:58:19.401191: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-07 22:58:19.426512: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-07 22:58:19.434085: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-08-07 22:58:19.454408: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-08-07 22:58:20.925099: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# #### Importing Data

# %%
data = pd.read_csv("AAPL_data.csv")

# %% [markdown]
# #### Data Pre-Processing

# %%
# Select only the 'close' column
data = data[['close']]

# Normalize the data
scaler = MinMaxScaler(feature_range=(0, 1))
data_scaled = scaler.fit_transform(data)

# %%
# Split data into train and test sets
train_size = int(len(data_scaled) * 0.7)
test_size = len(data_scaled) - train_size
train, test = data_scaled[0:train_size,
                          :], data_scaled[train_size:len(data_scaled), :]

# %%
# Function to create dataset
def create_dataset(dataset, time_steps=1):
    X, Y = [], []
    for i in range(len(dataset) - time_steps - 1):
        a = dataset[i:(i + time_steps), 0]
        X.append(a)
        Y.append(dataset[i + time_steps, 0])
    return np.array(X), np.array(Y)

# %%
# Time steps for LSTM
time_steps = 10

# Create the dataset with time steps
X_train, y_train = create_dataset(train, time_steps)
X_test, y_test = create_dataset(test, time_steps)

# %% [markdown]
# #### LSTM Model

# %%
# Reshape input to be [samples, time steps, features]
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# Build LSTM model
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(time_steps, 1)))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mean_squared_error')
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1723051701.983279   10320 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-08-07 22:58:21.988905: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2343] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# /home/shounakpaul/Documents/Code/Machine Learning/Projects/stock-market-prediction/.venv/lib64/python3.9/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# #### Training

# %%
# Train the model
model.fit(X_train, y_train, epochs=100, batch_size=64, verbose=1)
# Out:
# Epoch 1/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 0.0271
# Epoch 2/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 6.6603e-04
# Epoch 3/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 9.2182e-04
# Epoch 4/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 6.4809e-04
# Epoch 5/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 6.8445e-04
# Epoch 6/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 9.1956e-04
# Epoch 7/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 9.2060e-04
# Epoch 8/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.9185e-04
# Epoch 9/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5.4208e-04
# Epoch 10/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 7.0131e-04
# Epoch 11/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.2990e-04
# Epoch 12/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.0011
# Epoch 13/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.6292e-04
# Epoch 14/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5.6736e-04
# Epoch 15/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.9057e-04
# Epoch 16/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 8.6424e-04
# Epoch 17/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 5.8355e-04
# Epoch 18/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.8847e-04
# Epoch 19/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.4669e-04
# Epoch 20/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.9099e-04
# Epoch 21/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 5.1683e-04
# Epoch 22/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.5854e-04
# Epoch 23/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.4685e-04
# Epoch 24/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 7.2201e-04
# Epoch 25/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.1942e-04
# Epoch 26/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.4522e-04
# Epoch 27/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.8072e-04
# Epoch 28/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.7770e-04
# Epoch 29/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6048e-04
# Epoch 30/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.1018e-04
# Epoch 31/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.0001e-04
# Epoch 32/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.9672e-04
# Epoch 33/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 4.2513e-04
# Epoch 34/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3.8957e-04
# Epoch 35/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.1043e-04
# Epoch 36/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 6.8563e-04
# Epoch 37/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 5.0292e-04
# Epoch 38/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.3632e-04
# Epoch 39/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.7008e-04
# Epoch 40/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.0915e-04
# Epoch 41/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.7340e-04
# Epoch 42/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.0402e-04
# Epoch 43/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 5.0349e-04
# Epoch 44/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.5811e-04
# Epoch 45/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3.0216e-04
# Epoch 46/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3.3835e-04
# Epoch 47/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.5085e-04
# Epoch 48/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.3288e-04
# Epoch 49/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.2126e-04
# Epoch 50/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 2.4517e-04
# Epoch 51/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.2462e-04
# Epoch 52/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.8334e-04
# Epoch 53/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.0037e-04
# Epoch 54/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.1284e-04
# Epoch 55/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.5541e-04
# Epoch 56/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.1602e-04
# Epoch 57/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.1024e-04
# Epoch 58/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 8.0145e-05
# Epoch 59/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 6.2363e-04
# Epoch 60/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.5683e-04
# Epoch 61/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 8.0916e-05
# Epoch 62/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.9879e-04
# Epoch 63/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 3.3967e-04
# Epoch 64/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.5966e-04
# Epoch 65/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7043e-04
# Epoch 66/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 2.0642e-04
# Epoch 67/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.5866e-04
# Epoch 68/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.4051e-04
# Epoch 69/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 7.5587e-05
# Epoch 70/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.7917e-04
# Epoch 71/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 7.0911e-05
# Epoch 72/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.9152e-04
# Epoch 73/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.1577e-04
# Epoch 74/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.5257e-04
# Epoch 75/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.3831e-04
# Epoch 76/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 3.0330e-04
# Epoch 77/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 7.1416e-05
# Epoch 78/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 3.5201e-04
# Epoch 79/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 4.4539e-04
# Epoch 80/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.5420e-04
# Epoch 81/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.8444e-04
# Epoch 82/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.9211e-04
# Epoch 83/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 9.6142e-05
# Epoch 84/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.3122e-04
# Epoch 85/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.3638e-04
# Epoch 86/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.5186e-04
# Epoch 87/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 8.9506e-05
# Epoch 88/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 9.6220e-05
# Epoch 89/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.4687e-04
# Epoch 90/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 6.0682e-04
# Epoch 91/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.2725e-04
# Epoch 92/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.5976e-04
# Epoch 93/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.0807e-04
# Epoch 94/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.3183e-04
# Epoch 95/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.6416e-04
# Epoch 96/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.4083e-04
# Epoch 97/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.9713e-04
# Epoch 98/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 2.2914e-04
# Epoch 99/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.1331e-04
# Epoch 100/100
# 67/67 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.1907e-04

# %%
# Predictions
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)
# Out:
# 134/134 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
# Inverse transform predictions
train_predict = scaler.inverse_transform(train_predict)
y_train = scaler.inverse_transform([y_train])
test_predict = scaler.inverse_transform(test_predict)
y_test = scaler.inverse_transform([y_test])

# %% [markdown]
# #### Evaluation

# %%
# Calculate root mean squared error
train_score = np.sqrt(mean_squared_error(y_train[0], train_predict[:, 0]))
test_score = np.sqrt(mean_squared_error(y_test[0], test_predict[:, 0]))
print('Train RMSE: %.2f' % (train_score))
print('Test RMSE: %.2f' % (test_score))
# Out:
# Train RMSE: 10.08
# Test RMSE: 9.52

# %% [markdown]
# #### Visualization

# %%
# Plotting
plt.figure(figsize=(14, 6))
plt.plot(data.index[time_steps:time_steps+len(train_predict)],
         y_train[0], color='blue', label='Actual Train Data')
plt.plot(data.index[time_steps:time_steps+len(train_predict)],
         train_predict[:, 0], color='red', label='Predicted Train Data')
plt.plot(data.index[time_steps+len(train_predict)+1:time_steps+len(train_predict) +
         1+len(test_predict)], y_test[0], color='green', label='Actual Test Data')
plt.plot(data.index[time_steps+len(train_predict)+1:time_steps+len(train_predict)+1 +
         len(test_predict)], test_predict[:, 0], color='orange', label='Predicted Test Data')
plt.legend()
plt.title('AAPL Stock Price Prediction')
plt.xlabel('Date')
plt.ylabel('Stock Price')
plt.show()

# %% [markdown]
# #### Results:
# - **Train RMSE:** 10.08
# - **Test RMSE:** 9.52
